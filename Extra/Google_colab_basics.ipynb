# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelSdeSouza/astrostats-2025/blob/main/Google_colab_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of Google Colab
#
# Google Colaboratory or "Google Colab" for short, is an online platform that allows you to write and run Python code in your browser with no setup required. It provides a free, Jupyter Notebook-like environment with support for GPU acceleration.
#
# In this tutorial, we will go through a series of exercises to familiarize you with Google Colab and some of its useful features. \

# %% [markdown]
# ## Setting up your Google Colab environment
#
#
#
#
# 1.   Go to Google Colab.
# 2.   Sign in with your Google account.
# 1.   Click on File -> New notebook to create a new Colab notebook.

# %%
# Hello Colab
print("Hello, Google Colab!")
# Out:
# Hello, Google Colab!

# %%
# Importing libraries
import numpy as np

# %%
# Creating an array with NumPy
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
# Basic plotting with Matplotlib
import matplotlib.pyplot as plt

x = np.arange(0, 10, 1)
y = x**2

plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Simple Line Plot')
plt.show()

# %%
# Uploading a local file to Google Colab
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1f3fac39-4504-4014-8bdc-ce9576b3a8e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f3fac39-4504-4014-8bdc-ce9576b3a8e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Access the file, if a csv
import io
import pandas as pd

#df = pd.read_csv(io.BytesIO(uploaded['filename.csv']))

# %%
df.head()
# Out:
#    Consumption (kWh)                       Start                         End
# 0              0.007   2023-04-12T00:00:00+01:00   2023-04-12T00:30:00+01:00
# 1              0.005   2023-04-12T00:30:00+01:00   2023-04-12T01:00:00+01:00
# 2              0.018   2023-04-12T01:00:00+01:00   2023-04-12T01:30:00+01:00
# 3              0.019   2023-04-12T01:30:00+01:00   2023-04-12T02:00:00+01:00
# 4              0.004   2023-04-12T02:00:00+01:00   2023-04-12T02:30:00+01:00

# %%
# Accessing Google Drive files
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# List files
# !ls "/content/drive/My Drive" # uncomment to run

# %%
#Installing external Python packages
# !pip install astropy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.utils.data import download_file

# %%
image_file = download_file('http://data.astropy.org/tutorials/FITS-images/HorseHead.fits', cache=True )

# Load the FITS data
hdu_list = fits.open(image_file)
hdu_list.info()
# Out:
# Filename: /root/.astropy/cache/download/url/ff6e0b93871033c68022ca026a956d87/contents
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
image_data = hdu_list[0].data

# %%
plt.imshow(image_data, cmap='viridis')
plt.colorbar()

# %% [markdown]
# Click on File -> Download -> Download .ipynb to download your notebook as an IPython Notebook file.
#
# # References
#
#
#
# 1.   [https://www.astropy.org](https://www.astropy.org)
# 2.   [Get started with Google Colaboratory](https://www.youtube.com/watch?v=inN8seMm7UI)
